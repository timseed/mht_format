# %%
import MyTree
import networkx as nx
import matplotlib.pyplot as plt

mt=MyTree.MyTree()

jobs,job_pairs=mt.load_file("pic_uploads.txt",add_start=False)

for jp in job_pairs:
    mt.add_edge(jp[0],jp[1])

nx.draw_networkx(mt.net)
